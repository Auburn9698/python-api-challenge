# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#!pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial" # Set units
weather_list = []  # Create initial list
city_count = 1     # Start count of cities at 1

# Looping through list of cities:
for city in cities:
    # Build query url:
    query_url = f"{url}q={city}&APPID={weather_api_key}&units={units}"
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()

# Try and except for error handling (Day 2), grab all the weather items we need:
#  lat, Long, Humitidy, Max Temp, Cloudiness, Wind Speed, 
    try:
        city_lat = weather_json["coord"]["lat"]
        city_lng = weather_json["coord"]["lon"]
        max_temp = weather_json["main"]["temp_max"]
        humidity = weather_json["main"]["humidity"]
        cloudiness = weather_json["clouds"]["all"]
        wind_speed = weather_json["wind"]["speed"]
        country = weather_json["sys"]["country"]
        print(f"Processing City # {city_count}: {city}" )
        weather_list.append([city, city_lat, city_lng, max_temp, humidity, cloudiness, wind_speed, country ])
        city_count = city_count + 1
        time.sleep(1)  # Try it without this later, see if it takes less time.
        
    except(KeyError, IndexError):
        print("City was not found.")
# Out:
# Processing City # 1: caceres
# Processing City # 2: mataura
# Processing City # 3: batagay
# Processing City # 4: albany
# Processing City # 5: monopoli
# Processing City # 6: rikitea
# Processing City # 7: hithadhoo
# Processing City # 8: hermanus
# Processing City # 9: hervey bay
# Processing City # 10: port elizabeth
# Processing City # 11: ushuaia
# Processing City # 12: uaua
# Processing City # 13: east london
# Processing City # 14: ponta do sol
# Processing City # 15: belmopan
# Processing City # 16: khandyga
# Processing City # 17: latehar
# Processing City # 18: surgut
# Processing City # 19: lumphat
# Processing City # 20: san vicente
# Processing City # 21: port macquarie
# Processing City # 22: slave lake
# Processing City # 23: tigil
# Processing City # 24: birjand
# Processing City # 25: qaanaaq
# Processing City # 26: camacha
# Processing City # 27: miri
# Processing City # 28: bredasdorp
# Processing City # 29: mount gambier
# Processing City # 30: carballo
# Processing City # 31: thompson
# Processing City # 32: saint-philippe
# Processing City # 33: jamestown
# Processing City # 34: nishihara
# Processing City # 35: hilo
# Processing City # 36: puerto ayora
# Processing City # 37: parabel
# Processing City # 38: kapaa
# City was not found.
# Processing City # 39: hobart
# Processing City # 40: castro
# Processing City # 41: korla
# Processing City # 42: rognan
# Processing City # 43: bethel
# Processing City # 44: ariquemes
# Processing City # 45: ilulissat
# Processing City # 46: grand forks
# City was not found.
# Processing City # 47: jiazi
# Processing City # 48: atuona
# Processing City # 49: hobyo
# Processing City # 50: upernavik
# Processing City # 51: margate
# Processing City # 52: bud
# Processing City # 53: vaini
# Processing City # 54: cape town
# Processing City # 55: lipari
# Processing City # 56: kokoda
# Processing City # 57: chuy
# Processing City # 58: prykolotne
# Processing City # 59: weligama
# Processing City # 60: antofagasta
# Processing City # 61: kavieng
# Processing City # 62: cravo norte
# Processing City # 63: punta arenas
# Processing City # 64: cockburn town
# Processing City # 65: bluff
# Processing City # 66: mlonggo
# City was not found.
# Processing City # 67: geraldton
# Processing City # 68: whitehorse
# Processing City # 69: qaqortoq
# Processing City # 70: coihaique
# Processing City # 71: hasaki
# Processing City # 72: busselton
# Processing City # 73: uray
# Processing City # 74: batagay-alyta
# Processing City # 75: aviles
# Processing City # 76: klaksvik
# Processing City # 77: georgetown
# Processing City # 78: avarua
# Processing City # 79: los llanos de aridane
# Processing City # 80: kununurra
# Processing City # 81: karaton
# Processing City # 82: hailar
# Processing City # 83: barrow
# Processing City # 84: pitsunda
# Processing City # 85: galesong
# Processing City # 86: faya
# Processing City # 87: berlevag
# Processing City # 88: mehamn
# Processing City # 89: barabinsk
# Processing City # 90: luderitz
# Processing City # 91: jilin
# Processing City # 92: sitka
# Processing City # 93: uusikaupunki
# Processing City # 94: herat
# Processing City # 95: beisfjord
# Processing City # 96: taraz
# Processing City # 97: provideniya
# Processing City # 98: shiraz
# Processing City # 99: arraial do cabo
# Processing City # 100: jijiga
# Processing City # 101: dikson
# Processing City # 102: alma
# Processing City # 103: port alfred
# Processing City # 104: evensk
# Processing City # 105: airai
# Processing City # 106: bonavista
# Processing City # 107: ust-kuyga
# Processing City # 108: bama
# Processing City # 109: butaritari
# Processing City # 110: fort wellington
# Processing City # 111: salina cruz
# Processing City # 112: itaporanga
# City was not found.
# Processing City # 113: reconquista
# Processing City # 114: esperance
# City was not found.
# City was not found.
# City was not found.
# City was not found.
# Processing City # 115: mar del plata
# Processing City # 116: vestmannaeyjar
# Processing City # 117: idrinskoye
# Processing City # 118: rawson
# Processing City # 119: predejane
# Processing City # 120: sarakhs
# Processing City # 121: olafsvik
# Processing City # 122: pacific grove
# City was not found.
# Processing City # 123: san jeronimo
# Processing City # 124: saint george
# Processing City # 125: yerbogachen
# Processing City # 126: charleston
# Processing City # 127: alice springs
# Processing City # 128: tambovka
# Processing City # 129: tasiilaq
# Processing City # 130: deputatskiy
# Processing City # 131: isangel
# Processing City # 132: mossendjo
# Processing City # 133: faanui
# City was not found.
# Processing City # 134: khatanga
# Processing City # 135: erenhot
# City was not found.
# City was not found.
# Processing City # 136: tuktoyaktuk
# Processing City # 137: impfondo
# Processing City # 138: patzun
# Processing City # 139: vardo
# Processing City # 140: victoria
# Processing City # 141: golden
# Processing City # 142: omboue
# Processing City # 143: srednekolymsk
# Processing City # 144: ulladulla
# Processing City # 145: sola
# Processing City # 146: west bay
# Processing City # 147: sovetskiy
# Processing City # 148: cayenne
# Processing City # 149: anadyr
# Processing City # 150: tatawin
# Processing City # 151: noumea
# Processing City # 152: bloemfontein
# Processing City # 153: alofi
# Processing City # 154: torbay
# Processing City # 155: kalmunai
# Processing City # 156: tilichiki
# Processing City # 157: nykoping
# Processing City # 158: honningsvag
# Processing City # 159: nikolskoye
# City was not found.
# Processing City # 160: charters towers
# Processing City # 161: santiago
# Processing City # 162: manuk mangkaw
# Processing City # 163: iqaluit
# Processing City # 164: port hedland
# Processing City # 165: saint-augustin
# Processing City # 166: yellowknife
# Processing City # 167: pitimbu
# Processing City # 168: port said
# Processing City # 169: fortuna
# Processing City # 170: sampit
# Processing City # 171: megion
# Processing City # 172: lahij
# City was not found.
# Processing City # 173: weyburn
# Processing City # 174: jiangyou
# Processing City # 175: kodiak
# Processing City # 176: ocampo
# Processing City # 177: norman wells
# Processing City # 178: namibe
# Processing City # 179: kaitangata
# Processing City # 180: witu
# Processing City # 181: caravelas
# Processing City # 182: chokurdakh
# Processing City # 183: hamilton
# Processing City # 184: pontianak
# Processing City # 185: ribeira grande
# Processing City # 186: sao filipe
# Processing City # 187: muros
# Processing City # 188: santa cruz
# Processing City # 189: belyy yar
# Processing City # 190: havoysund
# Processing City # 191: paamiut
# Processing City # 192: alyangula
# Processing City # 193: spasskoye
# Processing City # 194: atar
# Processing City # 195: temple
# Processing City # 196: san mariano
# Processing City # 197: inverell
# Processing City # 198: rotherham
# Processing City # 199: sur
# Processing City # 200: wangqing
# Processing City # 201: teguldet
# Processing City # 202: ca mau
# Processing City # 203: rundu
# Processing City # 204: asau
# Processing City # 205: matay
# Processing City # 206: mackay
# Processing City # 207: warwick
# City was not found.
# Processing City # 208: muisne
# City was not found.
# Processing City # 209: podgorenskiy
# Processing City # 210: xiongzhou
# City was not found.
# City was not found.
# Processing City # 211: vidim
# Processing City # 212: tuatapere
# Processing City # 213: bad salzungen
# Processing City # 214: rio pardo
# Processing City # 215: leshukonskoye
# Processing City # 216: gimry
# Processing City # 217: souillac
# Processing City # 218: port pirie
# Processing City # 219: fukue
# Processing City # 220: yuzhno-kurilsk
# Processing City # 221: asosa
# Processing City # 222: abu samrah
# Processing City # 223: tiksi
# Processing City # 224: narsaq
# City was not found.
# Processing City # 225: lebu
# Processing City # 226: ozernovskiy
# Processing City # 227: harrismith
# Processing City # 228: salaverry
# Processing City # 229: amahai
# Processing City # 230: bam
# Processing City # 231: salinopolis
# Processing City # 232: voh
# Processing City # 233: manaus
# Processing City # 234: aklavik
# Processing City # 235: senador pompeu
# Processing City # 236: carnarvon
# City was not found.
# Processing City # 237: aykhal
# City was not found.
# City was not found.
# City was not found.
# Processing City # 238: deer lake
# Processing City # 239: miyako
# Processing City # 240: cabo san lucas
# Processing City # 241: gualeguay
# Processing City # 242: webster
# Processing City # 243: abha
# Processing City # 244: ancud
# Processing City # 245: jinxiang
# City was not found.
# Processing City # 246: tikhvin
# City was not found.
# Processing City # 247: mfou
# Processing City # 248: libourne
# Processing City # 249: pevek
# Processing City # 250: chany
# Processing City # 251: clyde river
# City was not found.
# Processing City # 252: thanh hoa
# Processing City # 253: banjarmasin
# Processing City # 254: varberg
# Processing City # 255: saint peter
# Processing City # 256: kasane
# Processing City # 257: butembo
# Processing City # 258: nome
# City was not found.
# Processing City # 259: craig
# Processing City # 260: xique-xique
# Processing City # 261: mahebourg
# Processing City # 262: neulengbach
# Processing City # 263: khandbari
# Processing City # 264: namatanai
# Processing City # 265: okhotsk
# Processing City # 266: peniche
# Processing City # 267: san diego
# Processing City # 268: corinto
# Processing City # 269: puerto madero
# Processing City # 270: chipinge
# Processing City # 271: acapulco
# City was not found.
# Processing City # 272: wanning
# Processing City # 273: novorossiysk
# City was not found.
# Processing City # 274: vao
# Processing City # 275: codrington
# Processing City # 276: partizanskoye
# Processing City # 277: mbaiki
# Processing City # 278: new norfolk
# City was not found.
# Processing City # 279: saskylakh
# City was not found.
# Processing City # 280: kruisfontein
# Processing City # 281: pisco
# Processing City # 488: kangema
# Processing City # 489: talara
# Processing City # 490: pochinki
# Processing City # 491: husavik
# Processing City # 492: yenagoa
# Processing City # 493: minsk
# Processing City # 494: kurumkan
# Processing City # 495: ratnagiri
# Processing City # 496: lokosovo
# Processing City # 497: katsuura
# Processing City # 498: yeppoon
# Processing City # 499: babol
# Processing City # 500: lazaro cardenas
# Processing City # 501: shingu
# Processing City # 502: williams lake
# Processing City # 503: olinda
# Processing City # 504: lagoa
# Processing City # 505: invermere
# Processing City # 506: ometepec
# Processing City # 507: auki
# Processing City # 508: wakkanai
# Processing City # 509: ostruznica
# Processing City # 510: mareeba
# Processing City # 511: ramygala
# Processing City # 512: filadelfia
# Processing City # 513: lai
# Processing City # 514: praia
# Processing City # 515: rosarito
# Processing City # 516: mezhdurechensk
# Processing City # 517: ponta grossa
# Processing City # 518: sao gabriel da cachoeira
# Processing City # 519: saquena
# Processing City # 520: cidreira
# Processing City # 521: jojoima
# Processing City # 522: nanortalik
# Processing City # 523: mwinilunga
# Processing City # 524: stephenville
# Processing City # 525: conceicao do araguaia
# Processing City # 526: chauk
# Processing City # 527: puerto colombia
# Processing City # 528: itupiranga
# Processing City # 529: opuwo
# Processing City # 530: bowen
# City was not found.
# Processing City # 531: shimoda
# Processing City # 532: muttupet
# Processing City # 533: mayor pablo lagerenza
# Processing City # 534: filingue
# Processing City # 535: novaya igirma
# Processing City # 536: yulara
# Processing City # 537: ketchikan
# Processing City # 538: necochea
# Processing City # 539: sharjah
# Processing City # 540: constitucion
# Processing City # 541: kumba
# Processing City # 542: half moon bay
# Processing City # 543: kuzino
# Processing City # 544: nanzhang
# Processing City # 545: langsa
# Processing City # 546: shubarkuduk
# Processing City # 547: juneau
# Processing City # 548: liverpool
# Processing City # 549: aras
# Processing City # 550: buenos aires
# Processing City # 551: dingle
# Processing City # 552: paralimni
# Processing City # 553: sirnak
# Processing City # 554: huarmey

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Turn the original list into a pandas DF:
weather_df = pd.DataFrame(weather_list)
#weather_df.head()

# Rename the columns from 0, 1, 2, 3, 4, 5, 6, 7 to real labels:
weather_df = weather_df.rename(columns ={0: "City", 1: "Latitude", 2: "Longitude", 3: "Max Temp",
                                        4: "Humidity", 5: "Cloudiness", 6: "Wind Speed", 7: "Country"})
weather_df.head()
# Out:
#        City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   caceres     39.52      -6.37     68.00        33           5        7.00
# 1   mataura    -46.19     168.86     35.01        92          77        3.00
# 2   batagay     67.63     134.63     15.66        95         100        3.98
# 3    albany     42.60     -73.97     64.99        64           0        6.73
# 4  monopoli     40.96      17.29     66.00        88          75       10.29
#
#   Country
# 0      ES
# 1      NZ
# 2      RU
# 3      US
# 4      IT

# %%
weather_df.to_csv("../Output/weather_df.csv", index = False, header = True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# See if there's a max humidity over 100:
weather_df.describe()

# No city with humidity over 100
# Out:
#          Latitude   Longitude    Max Temp    Humidity  Cloudiness  Wind Speed
# count  554.000000  554.000000  554.000000  554.000000  554.000000  554.000000
# mean    20.434206   19.185830   62.952545   68.958484   50.225632    8.294061
# std     33.488858   90.499713   20.280461   21.988820   37.466532    5.659740
# min    -54.800000 -175.200000   10.180000   10.000000    0.000000    0.310000
# 25%     -5.522500  -62.442500   48.200000   58.000000   11.000000    3.965000
# 50%     22.845000   23.630000   66.200000   73.500000   47.500000    6.965000
# 75%     49.365000  102.145000   78.640000   86.000000   89.000000   11.132500
# max     78.220000  179.320000  105.690000  100.000000  100.000000   32.210000

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Plot Latitude vs. Temperature:
latitudes = weather_df["Latitude"]
max_temps = weather_df["Max Temp"]

plt.scatter(latitudes, max_temps, facecolor = "blue", edgecolors = "black", alpha = 0.5 )
plt.title("Latitude vs. Maximum Temperature")
plt.xlabel("Laitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.show()


#plt.xlim(14, 26)
#plt.ylim(33, 47)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
latitudes = weather_df["Latitude"]
humidity = weather_df["Humidity"]

plt.scatter(latitudes, humidity, facecolor = "blue", edgecolors = "black", alpha = 0.5 )
plt.title("Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
latitudes = weather_df["Latitude"]
cloudiness = weather_df["Cloudiness"]

plt.scatter(latitudes, cloudiness, facecolor = "blue", edgecolors = "black", alpha = 0.5 )
plt.title("Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
latitudes = weather_df["Latitude"]
wind_speed = weather_df["Wind Speed"]

plt.scatter(latitudes, wind_speed, facecolor = "blue", edgecolors = "black", alpha = 0.5 )
plt.title("Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# From previous project:

# Calculate the correlation coefficient and linear regression model 

#x_values = weight_avg
#y_values = tumor_avg
#(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#regress_values = x_values * slope + intercept
#line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#plt.scatter(x_values,y_values)
#plt.plot(x_values,regress_values,"r-")
#plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#plt.xlabel('Weight (grams)')
#plt.ylabel('Tumor Volume (mm3)')
#plt.xlim(14, 26)
#plt.ylim(33, 47)
#print(f" The correlation coefficient between weight and tumor volume is {round(st.pearsonr(weight_avg, tumor_avg)[0],2)}")
#print(f" The r-squared is: {rvalue**2}")
#plt.grid(True)
#plt.show()

# %%
# Create dataframes for each hemisphere:

northern_df = weather_df.loc[weather_df["Latitude"] >= 0]
southern_df = weather_df.loc[weather_df["Latitude"] <= 0]
#northern_df.head()
southern_df.head()
# Out:
#          City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 1     mataura    -46.19     168.86     35.01        92          77
# 5     rikitea    -23.12    -134.97     73.63        78          22
# 6   hithadhoo     -0.60      73.08     83.44        74          82
# 7    hermanus    -34.42      19.23     69.44        58           1
# 8  hervey bay    -25.30     152.85     64.40        77          75
#
#    Wind Speed Country
# 1        3.00      NZ
# 5       17.96      PF
# 6       11.03      MV
# 7       10.20      ZA
# 8        9.17      AU

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_df["Latitude"]
y_values = northern_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(1, 20),fontsize=15,color="red")
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel('Maximum Temperature (F)')
print(f" The correlation coefficient between latitude and max temperature is {round(st.pearsonr(x_values, y_values)[0],2)}")
print(f" The r-squared is: {rvalue**2}")
plt.grid(True)
plt.show()
# Out:
#  The correlation coefficient between latitude and max temperature is -0.87
#  The r-squared is: 0.753112927449015

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_df["Latitude"]
y_values = southern_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55, 100),fontsize=15,color="red")
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel('Maximum Temperature (F)')
print(f" The correlation coefficient between latitude and max temperature is {round(st.pearsonr(x_values, y_values)[0],2)}")
print(f" The r-squared is: {rvalue**2}")
plt.grid(True)
plt.show()
# Out:
#  The correlation coefficient between latitude and max temperature is 0.68
#  The r-squared is: 0.4640707724832711

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
